# %% [markdown]
# # **NB 6.2: Targeted Entitiy Sentiment Identification**

# %% [markdown]
# ## Part 0: Importing Libraries

# %%
import os
import requests
import re
import sys
import regex as re
import ast

# %%
import nltk as nltk
import nltk.corpus  
from nltk.text import Text

# %%
import pandas as pd
import numpy as np
import sklearn

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
# Graphics in SVG format are more sharp and legible
# %config InlineBackend.figure_format = 'svg'
import warnings
warnings.filterwarnings("ignore")

# %%
# Multiprocessing

#pip install pandarallel
import multiprocessing

num_processors = multiprocessing.cpu_count()
print(f'Available CPUs: {num_processors}')

import pandarallel
from pandarallel import pandarallel
pandarallel.initialize(nb_workers=num_processors-1, use_memory_fs=False, progress_bar=True )
# Out:
# Available CPUs: 16
# INFO: Pandarallel will run on 15 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.

# %%
# Imports the Google Cloud client library

from google.cloud import storage
# Instantiates a client
storage_client = storage.Client()

# The name for the new bucket
bucket_name = "nlp_final_project_kshitijm"

# Creates the new bucket
bucket = storage_client.bucket(bucket_name)
print(f"Bucket {bucket.name} connected.")
# Out:
# Bucket nlp_final_project_kshitijm connected.

# %%
#Visuals

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set_style('white')
# Graphics in SVG format are more sharp and legible
# %config InlineBackend.figure_format = 'svg'

import warnings
warnings.filterwarnings("ignore")

from tqdm import tqdm

# %%
# Task specific
from collections import Counter
from itertools import chain

# %% [markdown]
# ## Part 1: Importing Datasets

# %%
# %%time
## Positive and Negative Sentiment Datasets

df_filt_pos=pd.read_csv('gs://nlp_final_project_kshitijm/00_Data/NLP_FP_Data7v3_POS_BERTopics_Sentiments_NER.csv',lineterminator='\n')
df_filt_neg=pd.read_csv('gs://nlp_final_project_kshitijm/00_Data/NLP_FP_Data7v4_NEG_BERTopics_Sentiments_NER.csv',lineterminator='\n')
# Out:
# CPU times: user 42.2 s, sys: 11.9 s, total: 54.1 s
# Wall time: 2min 22s

# %%
# We see the following organisations coming as most prominent from our entire dataset; across years
ORG_trend=pd.read_csv('NER_Trend_ORG.csv')
ORG_trend
# Out:
#                                     2020  \
# 0                          ('AI', 37756)
# 1                         ('V19', 28787)
# 2                      ('Google', 20518)
# 3                   ('Microsoft', 14155)
# 4                         ('IBM', 13379)
# 5     ('Artificial Intelligence', 12495)
# 6                          ('GR', 11260)
# 7                     ('Facebook', 9600)
# 8   ('Artificial Intelligence AI', 7383)
# 9                       ('Amazon', 6893)
# 10            ('Machine Learning', 6402)
# 11                       ('Intel', 6191)
# 12                       ('Apple', 5274)
# 13                          ('ML', 4460)
# 14                 ('AsiaPacific', 4086)
# 15                  ('Healthcare', 3892)
# 16                     ('Samsung', 3010)
# 17                     ('Twitter', 2701)
# 18                      ('Oracle', 2699)
# 19             ('IBM Corporation', 2665)
#
#                                          2021  \
# 0                               ('AI', 50705)
# 1                              ('V19', 21160)
# 2                 ('Gray Media Group', 19507)
# 3                           ('Google', 19109)
# 4                        ('Microsoft', 14261)
# 5          ('Artificial Intelligence', 13384)
# 6                              ('IBM', 13200)
# 7                         ('Facebook', 10079)
# 8                                ('GR', 9837)
# 9   ('Station20022021 Gray Television', 7721)
# 10                 ('Machine Learning', 7536)
# 11                               ('ML', 7343)
# 12       ('Artificial Intelligence AI', 7210)
# 13                           ('Amazon', 6835)
# 14                            ('Intel', 6033)
# 15                            ('Apple', 4753)
# 16                               ('EU', 4701)
# 17           ('BrandVoicePaid Program', 3981)
# 18                            ('Tesla', 3610)
# 19                       ('Healthcare', 3586)
#
#                                                  2022  \
# 0                                       ('AI', 71025)
# 1                         ('Gray Media Group', 54282)
# 2          ('Station20022022 Gray Television', 23401)
# 3                                   ('Google', 19290)
# 4                                       ('ML', 12760)
# 5                                       ('V19', 9213)
# 6                                 ('Microsoft', 7737)
# 7                                   ('ChatGPT', 7456)
# 8                                  ('Facebook', 7436)
# 9                                       ('IBM', 7204)
# 10  ('CaptioningAudio DescriptionA Gray Media Grou...
# 11                  ('Artificial Intelligence', 6591)
# 12                                   ('Amazon', 6109)
# 13                                     ('Meta', 5833)
# 14                                      ('DLE', 4885)
# 15                                       ('GR', 4471)
# 16                                  ('Twitter', 4422)
# 17                                ('Instagram', 4418)
# 18                                    ('Tesla', 4168)
# 19                         ('Machine Learning', 4153)
#
#                                           2023
# 0                          ('ChatGPT', 155292)
# 1                                ('AI', 84010)
# 2                         ('Microsoft', 53121)
# 3                            ('Google', 50085)
# 4                            ('OpenAI', 29117)
# 5                  ('Gray Media Group', 28657)
# 6                              ('Bard', 18375)
# 7   ('Station20022023 Gray Television', 12870)
# 8                        ('Microsofts', 10510)
# 9                           ('Googles', 10029)
# 10                          ('Facebook', 9210)
# 11                               ('GPT', 9033)
# 12                             ('Apple', 8173)
# 13                            ('Amazon', 7776)
# 14                       ('AIgenerated', 7114)
# 15                         ('Instagram', 7030)
# 16                           ('Twitter', 6972)
# 17                              ('Meta', 6379)
# 18                             ('Baidu', 5915)
# 19                                ('AP', 5846)

# %%
PER_trend=pd.read_csv('PER_Trend_ORG.csv')
PER_trend
# Out:
#                                                  2020  \
# 0                                      ('Size', 3979)
# 1                                     ('Trump', 3283)
# 2                                 ('Instagram', 1360)
# 3                         ('Middle EastAfrica', 1277)
# 4                                     ('Biden', 1046)
# 5                         ('Richests Richests', 1016)
# 6                                      ('Gebru', 886)
# 7                                  ('Ai Weiwei', 857)
# 8                                       ('Musk', 808)
# 9                                  ('Elon Musk', 779)
# 10                                    ('Trumps', 776)
# 11                                     ('Busco', 774)
# 12  ('asistencia tcnica para mi solucin de cuidado...
# 13                              ('Donald Trump', 704)
# 14                                    ('Pichai', 647)
# 15                                      ('BFSI', 613)
# 16                              ('Kyle Wiggers', 587)
# 17                             ('Sundar Pichai', 575)
# 18                                ('Jim Thorpe', 564)
# 19                       ('Mark My ServicesAll', 525)
#
#                                2021                              2022  \
# 0                    ('Size', 2994)               ('Elon Musk', 2219)
# 1                   ('Biden', 1993)                    ('Musk', 2192)
# 2                ('Closefor', 1908)                 ('Lemoine', 2044)
# 3               ('Greta Van', 1880)               ('Ai Weiwei', 1766)
# 4               ('Instagram', 1469)          ('Vectorspace AI', 1651)
# 5               ('Elon Musk', 1220)                   ('Biden', 1464)
# 6              ('Jim Thorpe', 1088)           ('EnterpriseFor', 1184)
# 7       ('Middle EastAfrica', 1087)         ('Mark Zuckerberg', 1066)
# 8        ('Su Tierra Tiempo', 1085)       ('StartedIs Bitcoin', 1006)
# 9                    ('Musk', 1080)                ('CoFounder', 961)
# 10                 ('DIIR F', 1060)                ('Greta Van', 951)
# 11         ('Greta Van     ', 1014)        ('SitesU.S. TVRadio', 881)
# 12                   ('Trump', 987)                 ('Standigm', 859)
# 13       ('Richests Richests', 984)                   ('Laivly', 854)
# 14                   ('Gebru', 851)                   ('Watson', 837)
# 15                ('Mitchell', 817)            ('Blake Lemoine', 816)
# 16  ('Greta Van SusterenGray', 788)                ('Instagram', 781)
# 17               ('Joe Biden', 754)                    ('Sophy', 768)
# 18               ('Ai Weiwei', 744)                   ('GShare', 684)
# 19         ('Greta Van      ', 743)  ('TVLatest NewscastsPress', 658)
#
#                        2023
# 0           ('Bing', 10618)
# 1            ('Musk', 8478)
# 2       ('Elon Musk', 7255)
# 3           ('Biden', 4333)
# 4           ('Trump', 4095)
# 5      ('Sam Altman', 3417)
# 6            ('Bard', 2638)
# 7   ('Sundar Pichai', 2584)
# 8          ('Pichai', 2359)
# 9       ('Ernie Bot', 2302)
# 10         ('Lessby', 2286)
# 11   ('Donald Trump', 2282)
# 12         ('Altman', 2020)
# 13  ('Satya Nadella', 1929)
# 14             ('Tu', 1808)
# 15          ('Putin', 1790)
# 16      ('Joe Biden', 1590)
# 17        ('Higgins', 1557)
# 18     ('Bill Gates', 1456)
# 19         ('Bidens', 1243)

# %% [markdown]
# ## Part 2: Extract Targeted Entities

# %%
def get_top_ents(df):

    df['ENT_ORG']=df['ENT_ORG'].parallel_apply(ast.literal_eval)
    org_list = list(chain.from_iterable(df['ENT_ORG']))
    counter_org = Counter(org_list)
    top_20_org = counter_org.most_common(20)
    
    df['ENT_PROD']=df['ENT_PROD'].parallel_apply(ast.literal_eval)
    prod_list = list(chain.from_iterable(df['ENT_PROD']))
    counter_prod = Counter(prod_list)
    top_20_prod = counter_prod.most_common(20)
    
    df['ENT_PER']=df['ENT_PER'].parallel_apply(ast.literal_eval)
    per_list = list(chain.from_iterable(df['ENT_PER']))
    counter_per = Counter(per_list)
    top_20_per = counter_per.most_common(20)
    
    df['ENT_NORP']=df['ENT_NORP'].parallel_apply(ast.literal_eval)
    norm_list = list(chain.from_iterable(df['ENT_NORP']))
    counter_norm = Counter(norm_list)
    top_20_norm = counter_norm.most_common(20)
    
    return top_20_org, top_20_prod, top_20_per, top_20_norm

# %%
# %%time
top_20_org_pos, top_20_prod_pos, top_20_per_pos, top_20_norm_pos = get_top_ents(df_filt_pos)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=4059), Label(value='0 / 4059'))), …
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=4059), Label(value='0 / 4059'))), …
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=4059), Label(value='0 / 4059'))), …
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=4059), Label(value='0 / 4059'))), …
# CPU times: user 4.28 s, sys: 4.65 s, total: 8.93 s
# Wall time: 10 s

# %%
POS_trend=pd.DataFrame({'ORGANIZATION':top_20_org_pos,'PRODUCT':top_20_prod_pos,'PERSON':top_20_per_pos, 'NORM':top_20_norm_pos})
POS_trend
# Out:
#                                          ORGANIZATION  \
# 0                                         (AI, 78573)
# 1                           (Gray Media Group, 60661)
# 2                                    (ChatGPT, 29275)
# 3                                     (Google, 23770)
# 4                                  (Microsoft, 22937)
# 5                                        (V19, 18860)
# 6            (Station20022022 Gray Television, 14059)
# 7                                         (ML, 13751)
# 8                                         (GR, 12167)
# 9                                        (IBM, 12077)
# 10                   (Artificial Intelligence, 11118)
# 11                                   (Facebook, 7543)
# 12  (CaptioningAudio DescriptionA Gray Media Group...
# 13                                     (Amazon, 7022)
# 14            (Station20022023 Gray Television, 6909)
# 15                                     (OpenAI, 6739)
# 16                           (Machine Learning, 6245)
# 17                                         (RD, 5219)
# 18                                      (Intel, 5184)
# 19                                      (Apple, 5166)
#
#                               PRODUCT                          PERSON  \
# 0                        (AI, 185906)                    (Size, 2140)
# 1                    (AIdriven, 5053)                    (Bing, 1887)
# 2                      (UsMeet, 2600)               (Greta Van, 1600)
# 3                         (HPC, 1718)               (Elon Musk, 1561)
# 4                      (Cresta, 1472)                   (Biden, 1411)
# 5                        (Bing, 1435)                   (Trump, 1258)
# 6                         (V19, 1430)                (Standigm, 1250)
# 7                          (SE, 1271)                (Closefor, 1228)
# 8                         (CRM, 1263)               (CoFounder, 1181)
# 9                (Google Cloud, 1115)                  (Laivly, 1117)
# 10                 (JavaScript, 1029)                    (Musk, 1112)
# 11                        (ADAS, 899)                   (Telixs, 960)
# 12              (NewscastsPress, 821)           (Greta Van     , 898)
# 13                  (FDAcleared, 723)                     (Weve, 843)
# 14                       (Cloud, 721)  (TVLatest NewscastsPress, 830)
# 15                     (Windows, 719)        (Middle EastAfrica, 787)
# 16  (FNAlle  im BlickpunktAd   , 587)                   (Watson, 759)
# 17                     (YouTube, 586)                      (von, 757)
# 18                     (Akismet, 567)                     (BFSI, 751)
# 19                 (Fortune 500, 546)               (anlegenWas, 747)
#
#                      NORM
# 0         (Chinese, 5935)
# 1        (European, 3026)
# 2        (Canadian, 2659)
# 3        (American, 2109)
# 4         (British, 1650)
# 5       (Americans, 1401)
# 6          (French, 1268)
# 7          (German, 1229)
# 8           (Lunit, 1080)
# 9           (Korean, 992)
# 10  (North American, 938)
# 11       (Canadians, 924)
# 12         (African, 827)
# 13           (Asian, 788)
# 14           (Irish, 623)
# 15           (Saudi, 585)
# 16             (ian, 555)
# 17         (Italian, 545)
# 18           (Swiss, 532)
# 19         (Spanish, 529)

# %% [markdown]
# * POS: ChatGPT, Microsoft,
# * POS: Google + Alphabet - Bard
# * POS: Coinbase, Ethereum

# %%
# %%time
top_20_org_neg, top_20_prod_neg, top_20_per_neg, top_20_norm_neg = get_top_ents(df_filt_neg)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=313), Label(value='0 / 313'))), HB…
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=313), Label(value='0 / 313'))), HB…
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=313), Label(value='0 / 313'))), HB…
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=313), Label(value='0 / 313'))), HB…
# CPU times: user 1.15 s, sys: 3.17 s, total: 4.31 s
# Wall time: 5.57 s

# %%
NEG_trend=pd.DataFrame({'ORGANIZATION':top_20_org_neg,'PRODUCT':top_20_prod_neg,'PERSON':top_20_per_neg, 'NORM':top_20_norm_neg})
NEG_trend
# Out:
#                              ORGANIZATION                    PRODUCT  \
# 0                         (ChatGPT, 5924)                (AI, 11450)
# 1                              (AI, 5642)                (Bing, 477)
# 2                          (Google, 5628)                  (SE, 353)
# 3                       (Microsoft, 3025)       (SoundHound AI, 318)
# 4                            (Bard, 1994)            (Coinbase, 231)
# 5                         (Googles, 1882)                  (XT, 129)
# 6               (Matrix AI Network, 1701)  (Matrix AI Networks, 127)
# 7                             (V19, 1307)           (Nebula AI, 123)
# 8           (Lisk Machine Learning, 1248)            (AIdriven, 116)
# 9                        (Ethereum, 1197)          (JavaScript, 107)
# 10                       (Facebook, 1190)             (Twitter, 103)
# 11                       (Alphabet, 1153)                  (V19, 89)
# 12                          (OpenAI, 997)           (AccountNow, 82)
# 13                      (Microsofts, 946)              (YouTube, 77)
# 14  (Decentralized Machine Learning, 936)           (Windows 11, 76)
# 15                              (SE, 827)          (ChatGPT.Led, 71)
# 16       (Guardforce AI Co. Limited, 770)              (Stellar, 65)
# 17                         (Twitter, 769)              (Akismet, 65)
# 18                  (Facebook Share, 751)            (Matrix AI, 62)
# 19                           (Apple, 745)              (Windows, 62)
#
#                    PERSON               NORM
# 0   (Vectorspace AI, 992)    (Chinese, 1393)
# 1             (Bing, 473)    (European, 458)
# 2        (Ernie Bot, 460)    (American, 385)
# 3        (Elon Musk, 440)   (Canadians, 302)
# 4             (Musk, 429)   (Americans, 268)
# 5            (Trump, 350)    (Canadian, 259)
# 6            (Biden, 331)     (British, 250)
# 7    (Sundar Pichai, 301)     (Italian, 242)
# 8      (Vectorspace, 275)      (French, 198)
# 9            (Putin, 207)      (German, 166)
# 10           (Ernie, 193)  (Clearviews, 137)
# 11            (Bard, 171)   (Ukrainian, 126)
# 12     (theresearch, 168)    (Polymath, 123)
# 13          (Pichai, 145)       (Hindu, 121)
# 14    (loweragainst, 145)       (Saudi, 120)
# 15      (Sam Altman, 143)         (EUs, 106)
# 16           (Gebru, 140)   (Europeans, 105)
# 17            (NAAQ, 135)   (Republican, 90)
# 18        (Snapchat, 131)        (Asian, 86)
# 19     (Syscoin SYS, 128)          (ian, 83)

# %% [markdown]
# * NEG: Vectorspace AI - ML Based Blockchain
# * NEG: Google + Alphabet - Bard
# * NEG: Coinbase, Ethereum

# %%
len(df_filt_neg.Bert_topics.unique())
# Out:
# 40

# %% [markdown]
# ----
# ## Part 3: Entities from Topics with a positive sentiment

# %%
def get_top_ents_2(df):

    df['ENT_ORG']=df['ENT_ORG'].parallel_apply(ast.literal_eval)
    org_list = list(chain.from_iterable(df['ENT_ORG']))
    counter_org = Counter(org_list)
    top_20_org = counter_org.most_common(20)
    
    df['ENT_PROD']=df['ENT_PROD'].parallel_apply(ast.literal_eval)
    prod_list = list(chain.from_iterable(df['ENT_PROD']))
    counter_prod = Counter(prod_list)
    top_20_prod = counter_prod.most_common(20)
    
    df['ENT_PER']=df['ENT_PER'].parallel_apply(ast.literal_eval)
    per_list = list(chain.from_iterable(df['ENT_PER']))
    counter_per = Counter(per_list)
    top_20_per = counter_per.most_common(20)
    
    df['ENT_NORP']=df['ENT_NORP'].parallel_apply(ast.literal_eval)
    norm_list = list(chain.from_iterable(df['ENT_NORP']))
    counter_norm = Counter(norm_list)
    top_20_norm = counter_norm.most_common(20)
    
    ent_trend_df=pd.DataFrame({'ORGANIZATION':top_20_org,'PRODUCT':top_20_prod,'PERSON':top_20_per, 'NORM':top_20_norm})
    return ent_trend_df

# %%
# ConvAI
df_filt_pos_convai=df_filt_pos[df_filt_pos.Bert_topics==1]
df_filt_pos_convai.ENT_ORG.sample(2)
top_20_org_pos_convai, top_20_prod_pos_convai, top_20_per_pos_convai, top_20_norm_pos_convai = get_top_ents_2(df_filt_pos_convai)

# %%
POS_trend=pd.DataFrame({'ORGANIZATION':top_20_org_pos_convai,'PRODUCT':top_20_prod_pos_convai,'PERSON':top_20_per_pos_convai, 'NORM':top_20_norm_pos_convai})
POS_trend
# Out:
#                ORGANIZATION             PRODUCT                 PERSON  \
# 0           (ChatGPT, 7931)          (AI, 7524)            (Bing, 958)
# 1         (Microsoft, 4352)         (Bing, 670)       (Elon Musk, 504)
# 2                (AI, 3397)          (HPC, 474)            (Musk, 329)
# 3            (Google, 2744)  (Magellan AI, 401)      (Sam Altman, 243)
# 4            (OpenAI, 2496)    (SageMaker, 244)   (Satya Nadella, 204)
# 5               (IBM, 1390)     (Synopsys, 215)          (Pichai, 114)
# 6             (Amazon, 983)      (Windows, 126)   (Sundar Pichai, 109)
# 7         (Microsofts, 811)         (Core, 110)          (Altman, 107)
# 8   (Gray Media Group, 765)      (Magellan, 89)    (Kyle Wiggers, 101)
# 9            (Samsung, 574)       (Open AI, 89)          (Watson, 101)
# 10         (Darktrace, 519)    (Windows 11, 86)             (SNPS, 84)
# 11              (GPT3, 501)    (JavaScript, 69)  (Gokul Ganapathi, 80)
# 12               (GPT, 492)      (AIdriven, 66)    (Greg Brockman, 72)
# 13           (Googles, 484)           (PRX, 65)          (Krishna, 70)
# 14              (Dell, 462)          (Word, 59)            (Trump, 68)
# 15                (ML, 432)     (DeepMinds, 58)              (Koo, 65)
# 16    (Facebook Share, 419)            (SE, 56)            (Biden, 64)
# 17             (Apple, 381)       (YouTube, 56)        (Bing Chat, 62)
# 18            (GPT3.5, 372)         (Excel, 55)           (Claude, 61)
# 19              (Bard, 371)      (DeepMind, 50)          (Bing AI, 58)
#
#                    NORM
# 0        (Chinese, 142)
# 1         (Oracles, 91)
# 2        (Canadian, 73)
# 3        (American, 69)
# 4          (French, 68)
# 5          (German, 66)
# 6         (British, 61)
# 7        (European, 51)
# 8         (Italian, 42)
# 9       (Canadians, 38)
# 10          (Musks, 35)
# 11       (Duolingo, 33)
# 12  (dataintensive, 33)
# 13    (Republicans, 31)
# 14      (Americans, 29)
# 15          (Hindu, 29)
# 16     (Similarweb, 26)
# 17   (LOOPExisting, 23)
# 18           (sLiz, 23)
# 19          (Asian, 22)

# %%
# GREG BROCKMAN, SAM ALTMAN, SATYA NADELLA

# %%
# Healthcare
df_filt_pos_health=df_filt_pos[df_filt_pos.Bert_topics.isin([2])]
ent_trend_health = get_top_ents_2(df_filt_pos_health)
ent_trend_health

# ROCHE, BAYER, IBM
# DRUG DISCOVERY, APACHE KYLIN
# EUROPEAN COMPANIES
# Out:
#                          ORGANIZATION                    PRODUCT  \
# 0                          (AI, 3255)                 (AI, 6519)
# 1                         (V19, 1541)            (AIdriven, 153)
# 2                          (GR, 1170)               (Galen, 139)
# 3            (Gray Media Group, 1071)           (Discovery, 117)
# 4      (Artificial Intelligence, 991)                 (V19, 113)
# 5                   (Healthcare, 906)                 (L001, 95)
# 6                        (Roche, 894)                   (CS, 77)
# 7                       (Google, 814)              (Us2.ais, 73)
# 8                   (healthcare, 568)     (Discovery Market, 60)
# 9                          (IBM, 495)           (FDAcleared, 52)
# 10  (Artificial Intelligence AI, 464)    (FirstEver AI Test, 52)
# 11                   (Microsoft, 408)                (uPath, 48)
# 12                          (RD, 347)             (Ibexs AI, 46)
# 13                     (ChatGPT, 324)        (Galenplatform, 46)
# 14                       (Bayer, 313)  (VistaPath Raises 4M, 46)
# 15                      (Us2.ai, 290)              (SubtleD, 42)
# 16                 (AsiaPacific, 285)               (AiCure, 38)
# 17                         (NLP, 278)               (UsMeet, 36)
# 18                          (ML, 274)   (About AidocAidocis, 36)
# 19             (Computer Vision, 248)     (minutes.2Us2.ais, 35)
#
#                      PERSON                  NORM
# 0           (Medipath, 494)       (European, 171)
# 1               (Size, 202)        (British, 111)
# 2        (Kylin Cloud, 136)         (Chinese, 99)
# 3       (Amarasingham, 120)        (American, 63)
# 4               (Trump, 84)        (Canadian, 58)
# 5        (Seth Koeppel, 71)       (Americans, 55)
# 6             (Cyclica, 70)          (German, 48)
# 7            (Closefor, 67)        (Comperat, 41)
# 8   (Middle EastAfrica, 62)        (AidocThe, 36)
# 9                (Ibex, 61)           (Irish, 32)
# 10          (Michalski, 60)            (Arab, 32)
# 11            (Ritchie, 60)  (North American, 26)
# 12          (SanyalDey, 60)   (Revolutionize, 25)
# 13            (Dedalus, 56)          (French, 24)
# 14        (Cardiosense, 56)            (AIML, 24)
# 15               (Xray, 53)         (African, 22)
# 16      (Joseph Mossel, 53)       (Democrats, 22)
# 17              (Olive, 49)          (Korean, 21)
# 18          (Greta Van, 49)     (Maharashtra, 17)
# 19        (Jill German, 48)        (Scottish, 17)

# %%
# Financial
df_filt_pos_fin=df_filt_pos[df_filt_pos.Bert_topics.isin([3])]
ent_trend_fin = get_top_ents_2(df_filt_pos_fin)
ent_trend_fin
# Out:
#                                          ORGANIZATION  \
# 0                           (Matrix AI Network, 1681)
# 1                                          (AI, 1410)
# 2                       (Lisk Machine Learning, 1204)
# 3                   (Guardforce AI Co. Limited, 1097)
# 4                                        (GFAI, 1043)
# 5                                 (Renalytix AI, 959)
# 6                                     (Ethereum, 911)
# 7                                           (SE, 908)
# 8               (Decentralized Machine Learning, 608)
# 9   (First Trust Nasdaq Artificial Intelligence an...
# 10                       (Link Machine Learning, 565)
# 11                                         (SEC, 550)
# 12                              (Facebook Share, 542)
# 13                              (LinkedIn Share, 540)
# 14                  (Global X  Intelligence ETF, 490)
# 15                          (SES AI Corporation, 417)
# 16                                     (ChatGPT, 416)
# 17                                         (SES, 387)
# 18                                      (SES AI, 384)
# 19                                  (CryptoBeat, 377)
#
#                                               PRODUCT  \
# 0                                          (AI, 3058)
# 1                                (SoundHound AI, 519)
# 2                                           (SE, 353)
# 3                                     (Coinbase, 165)
# 4                           (Matrix AI Networks, 122)
# 5                                     (AIdriven, 119)
# 6                                            (XT, 99)
# 7                                            (NA, 79)
# 8                                     (Matrix AI, 58)
# 9                                    (PrepCreate, 56)
# 10                                   (Overweight, 37)
# 11                                        (AI NA, 33)
# 12                               (AI Competitors, 30)
# 13                                        (NA NA, 29)
# 14                                      (Stellar, 26)
# 15                                    (Allegions, 26)
# 16  (Etrade ReviewReview Interactive Brokers Revie...
# 17                                 (Lisk Machine, 25)
# 18                                (Guardforce AI, 24)
# 19  (Share Market Snapshot Stock Gestures Trading ...
#
#                      PERSON                  NORM
# 0      (Guardforce AI, 242)        (Chinese, 264)
# 1         (Guardforce, 166)       (Canadian, 219)
# 2      (N. Charles St, 137)      (Canadians, 180)
# 3        (Syscoin SYS, 128)       (Polymath, 124)
# 4              (Biden, 128)        (American, 91)
# 5               (NAAQ, 123)        (European, 72)
# 6       (XeniosCoin X, 113)           (Asian, 46)
# 7        (theresearch, 113)        (Houndify, 38)
# 8         (Jim Cramer, 108)       (Americans, 34)
# 9             (Censia, 108)          (German, 34)
# 10         (Bytom BTM, 106)          (French, 33)
# 11             (Trump, 102)          (PREVIO, 31)
# 12          (Elon Musk, 88)         (British, 28)
# 13  (Email WebsiteSave, 85)       (Democrats, 26)
# 14       (loweragainst, 79)      (Technavios, 24)
# 15          (Dont Miss, 71)       (MoganLuke, 24)
# 16           (Benzinga, 70)          (Muslim, 23)
# 17               (GFAI, 70)  (North American, 21)
# 18    (Louis Navellier, 68)          (Rivian, 21)
# 19            (Dai DAI, 68)           (Tamil, 20)

# %%
# HARDWARE
df_filt_pos_gpu=df_filt_pos[df_filt_pos.Bert_topics.isin([6])]
ent_trend_gpu = get_top_ents_2(df_filt_pos_gpu)
ent_trend_gpu
# Out:
#                       ORGANIZATION                       PRODUCT  \
# 0                   (Nvidia, 2490)                    (AI, 4313)
# 1                       (AI, 2002)                    (HPC, 331)
# 2               (Supermicro, 1220)                   (A100, 190)
# 3          (Gray Media Group, 592)                (Rescale, 112)
# 4                     (Intel, 523)                   (Core, 109)
# 5                       (GPU, 508)               (DGX Cloud, 86)
# 6                 (Microsoft, 408)             (Tensor Core, 83)
# 7                   (ChatGPT, 363)           (AI Enterprise, 71)
# 8                   (Nvidias, 320)                (AIdriven, 53)
# 9                        (GR, 300)  (Universal GPU Platform, 49)
# 10                   (Google, 295)            (Supercluster, 48)
# 11                      (DGX, 285)              (JavaScript, 42)
# 12            (AI Enterprise, 284)                    (DLSS, 42)
# 13  (Artificial Intelligence, 257)             (SuperBlades, 33)
# 14             (Shutterstock, 243)               (L4 Tensor, 31)
# 15     (Super Micro Computer, 203)               (PicMonkey, 30)
# 16                   (Oracle, 197)                  (Xilinx, 29)
# 17           (Micro Computer, 179)               (Metaverse, 29)
# 18     (Omniverse Enterprise, 169)              (Javascript, 25)
# 19                      (HGX, 163)                    (V100, 23)
#
#                                   PERSON                  NORM
# 0                         (Nvidias, 340)        (Chinese, 102)
# 1                     (Supermicros, 213)    (topoftheline, 49)
# 2                           (Huang, 156)         (Oracles, 44)
# 3                    (Jensen Huang, 155)  (North American, 27)
# 4                   (Charles Liang, 101)        (European, 24)
# 5                         (Ian Buck, 64)            (A100, 20)
# 6                          (Picasso, 58)        (American, 16)
# 7                    (highbandwidth, 57)        (Canadian, 14)
# 8                      (Manuvir Das, 55)           (Linux, 14)
# 9                   (Justin Boitano, 48)          (German, 14)
# 10                    (workflowfrom, 48)         (British, 13)
# 11                            (Size, 47)       (Canadians, 12)
# 12                     (Omri Geller, 43)         (Popular, 11)
# 13                        (Cloudera, 36)               (C., 8)
# 14                      (George Lin, 34)       (Technavios, 8)
# 15                      (Greg Estes, 33)      (Maharashtra, 8)
# 16  (Inferencing Workloads SAN JOSE, 33)       (ServiceFCC, 8)
# 17                   (Kevin Connors, 33)            (Asian, 7)
# 18                   (Paul Hennessy, 30)           (Aussie, 7)
# 19                            (BFSI, 29)            (Saudi, 7)

# %%
# HPC - High Performance Computing: NEW INDUSTRY
# NVIDIA, Intel
# NVIDIA DGX
# NVIDIA - Jensen Huang, Ian Buck, Manuvir Das

# %%
# LEGAL
df_filt_pos_legal=df_filt_pos[df_filt_pos.Bert_topics.isin([10])]
ent_trend_legal = get_top_ents_2(df_filt_pos_legal)
ent_trend_legal
# Out:
#                                          ORGANIZATION  \
# 0                                          (AI, 1173)
# 1                             (Gray Media Group, 658)
# 2                                     (Deloitte, 450)
# 3                                     (Casetext, 397)
# 4                                      (Styldod, 373)
# 5                                    (Deloittes, 289)
# 6                            (Legal AI Software, 225)
# 7                                         (DTTL, 208)
# 8                                  (Venture MLS, 199)
# 9                                 (S Scientific, 191)
# 10                                     (ChatGPT, 175)
# 11                               (S Scientifics, 174)
# 12                                         (MLS, 169)
# 13                                   (LegalTech, 165)
# 14             (Station20022022 Gray Television, 155)
# 15             (Station20022023 Gray Television, 131)
# 16                                  (LexisNexis, 115)
# 17                                 (Metaphysics, 108)
# 18  (CaptioningAudio DescriptionA Gray Media Group...
# 19                                    (Everlaws, 102)
#
#                             PRODUCT                       PERSON  \
# 0                        (AI, 2259)             (CoCounsel, 577)
# 1                      (UsMeet, 44)               (Everlaw, 202)
# 2                        (Root, 42)            (Metaphysic, 198)
# 3                  (CoCounsels, 36)           (EvolutionIQ, 142)
# 4                    (AIdriven, 34)          (Thomas Salama, 72)
# 5                  (Tractables, 30)             (Ediscovery, 69)
# 6    (Ediscovery Platform Skip, 30)                    (Ian, 56)
# 7               (Tractables AI, 28)               (Sam Head, 54)
# 8                          (Tn, 20)                 (Salama, 54)
# 9                          (7M, 18)                 (Bourne, 54)
# 10                 (RealMoment, 14)    (Casetexts CoCounsel, 46)
# 11                        (V19, 13)           (Dan Helfrich, 45)
# 12             (NewscastsPress, 10)         (Michael Segala, 45)
# 13               (Generative AI, 9)           (Nitin Mittal, 43)
# 14              (Trustworthy AI, 9)              (firmsfrom, 41)
# 15                (JobsHometown, 7)                (Lunawat, 40)
# 16  (ConnectBusiness BreakPOAST, 7)       (Creator Sam Head, 36)
# 17                    (TVGray  , 7)     (Leads Scott Bourne, 36)
# 18                     (Akismet, 6)  (Matteo OlivieriDancey, 36)
# 19                      (Towers, 6)           (Scott Bourne, 36)
#
#                                            NORM
# 0                                (Flyreel, 196)
# 1                                   (Epiqs, 24)
# 2                               (Casetexts, 23)
# 3                               (Americans, 21)
# 4                               (Ukrainian, 19)
# 5                                     (Han, 18)
# 6                                 (agoWith, 17)
# 7                                   (Sabah, 14)
# 8                                 (Chinese, 13)
# 9                                (American, 13)
# 10                               (European, 11)
# 11                                (Sarawak, 11)
# 12                                 (Turkish, 8)
# 13                            (settlementin, 8)
# 14                          (FrostSullivans, 8)
# 15  (Technologies1.201.962.6091carley.bunch, 8)
# 16                                   (Hindu, 8)
# 17                                 (British, 7)
# 18                                (Origamis, 6)
# 19                                  (Inmans, 6)

# %%
# Casetext
# Deloittes
# Everlaw
# Dan Helfrich

# %%
# music
df_filt_pos_mus=df_filt_pos[df_filt_pos.Bert_topics.isin([13])]
ent_trend_mus = get_top_ents_2(df_filt_pos_mus)
ent_trend_mus
# Out:
#                                    ORGANIZATION                     PRODUCT  \
# 0                       (Gray Media Group, 587)                  (AI, 1375)
# 1                                (Verbits, 498)               (Verbit, 442)
# 2                       (Pro Music Rights, 483)          (Google Cloud, 43)
# 3                                     (AI, 438)                    (VI, 33)
# 4                                 (TikTok, 425)                (Galaxy, 27)
# 5                        (Music Licensing, 308)         (D 101 million, 27)
# 6                                 (Google, 271)               (Open AI, 22)
# 7                                 (Verbit, 226)            (SoundCloud, 18)
# 8                              (ByteDance, 223)                (UsMeet, 17)
# 9                               (Musicube, 211)  (User Management Pack, 16)
# 10                               (ChatGPT, 202)                    (VS, 16)
# 11                          (Stability AI, 199)               (YouTube, 11)
# 12                           (AIgenerated, 166)               (Windows, 11)
# 13                  (Third Point Ventures, 162)                    (VR, 11)
# 14                               (Spotify, 145)            (JavaScript, 10)
# 15                             (Microsoft, 132)                 (Pixel, 10)
# 16                                 (Apple, 113)                (Pro AI, 10)
# 17  (the Worlds Leading Voice AI Platform, 108)              (WT2 Edge, 10)
# 18       (Station20022022 Gray Television, 108)                    (M2, 10)
# 19                             (Waterdrop, 108)              (YouTubers, 9)
#
#                     PERSON                  NORM
# 0         (Musicubes, 152)     (Songtradrs, 102)
# 1         (Metaphysic, 95)          (Jaxsta, 51)
# 2     (Huang Mingxing, 72)       (Songtradr, 51)
# 3              (Biden, 68)  (visitSONGTRADR, 49)
# 4          (Tom Livne, 56)         (Chinese, 24)
# 5               (Tori, 56)          (French, 21)
# 6      (Emad Mostaque, 55)        (Sonantic, 17)
# 7    (Robert Schwartz, 54)           (tier1, 16)
# 8     (Paul Wiltshire, 51)          (German, 13)
# 9         (David Hoga, 51)        (Canadian, 13)
# 10           (Song Zu, 51)          (Korean, 12)
# 11  (Kara GaughanJive, 49)        (American, 11)
# 12   (MICUBEPublished, 45)           (Swiss, 11)
# 13      (Hamburgbased, 45)         (Swedish, 11)
# 14      (Jake P. Noch, 44)         (British, 10)
# 15          (Pharrell, 44)             (ian, 10)
# 16       (Young Jeezy, 44)          (Arabic, 10)
# 17        (Lil Yachty, 44)          (Italian, 9)
# 18             (Larry, 44)         (European, 9)
# 19        (Trae Pound, 44)          (African, 9)

# %% [markdown]
# ----
# ## Entities in Topics from Negative Sentiment

# %%
# CRYPTOGRAPHY
df_filt_neg_crypto=df_filt_neg[df_filt_neg.Bert_topics.isin([0])]
ent_trend_cryto = get_top_ents_2(df_filt_neg_crypto)
ent_trend_cryto
# Out:
#                              ORGANIZATION  \
# 0               (Matrix AI Network, 1640)
# 1           (Lisk Machine Learning, 1223)
# 2                        (Ethereum, 1128)
# 3   (Decentralized Machine Learning, 812)
# 4            (Link Machine Learning, 622)
# 5                       (CryptoBeat, 508)
# 6                      (NewsUpdates, 497)
# 7                 (Machine Learning, 434)
# 8                   (Facebook Share, 416)
# 9                   (LinkedIn Share, 416)
# 10                              (SE, 410)
# 11                             (SEC, 398)
# 12                          (Gemini, 348)
# 13                     (RatingsNews, 280)
# 14                             (DML, 271)
# 15                (currencys Github, 244)
# 16                (Virtus AllianzGI, 236)
# 17                             (LML, 232)
# 18                   (Twitter Share, 211)
# 19                              (DT, 207)
#
#                                               PRODUCT  \
# 0                                     (Coinbase, 218)
# 1                                           (SE, 210)
# 2                                           (AI, 169)
# 3                                    (Nebula AI, 123)
# 4                           (Matrix AI Networks, 120)
# 5                                    (AccountNow, 80)
# 6                                            (XT, 73)
# 7                                       (Stellar, 60)
# 8                                     (Matrix AI, 59)
# 9                                      (CoinBene, 33)
# 10                                 (Lisk Machine, 27)
# 11                            (X Artificial  ETF, 20)
# 12                                 (FundComplete, 20)
# 13                                    (Cryptopia, 18)
# 14                                   (DaysPosted, 15)
# 15                                     (ROGin AI, 14)
# 16  (Matrix AI Network Token Trading Matrix AI Net...
# 17                          (BitBay andCryptopia, 13)
# 18                       (FundsQRAFT AI Enhanced, 13)
# 19                                           (MX, 11)
#
#                                              PERSON             NORM
# 0                             (Vectorspace AI, 979)  (Polymath, 118)
# 1                                (Vectorspace, 272)   (Chinese, 118)
# 2                               (loweragainst, 139)   (Canadian, 45)
# 3                                (Syscoin SYS, 123)  (Canadians, 42)
# 4                               (XeniosCoin X, 102)     (PREVIO, 30)
# 5                                  (Bytom BTM, 101)   (Ethfinex, 22)
# 6                                (ChangeChange, 80)     (Enegra, 14)
# 7                                     (Dai DAI, 73)      (0.0148, 9)
# 8                    (FilingsDaily RatingsNews, 64)   (Democrats, 8)
# 9                                (RequiredMail, 64)     (British, 7)
# 10                                 (LearningIt, 59)      (German, 7)
# 11                                  (DXdao DXD, 54)       (isThe, 6)
# 12                                  (NetworkIt, 49)     (Swingby, 6)
# 13                                       (NAAQ, 47)     (Emirati, 6)
# 14  (Frutarom Gramercy Property To Be Acquired, 46)    (European, 5)
# 15                                     (Gibson, 46)  (Democratic, 5)
# 16                                (theresearch, 42)   (Ukrainian, 4)
# 17                                     (Kucoin, 41)    (DaysWKRB, 4)
# 18                     (Vectorspace AIComplete, 39)   (Americans, 4)
# 19                    (Vectorspace AI Complete, 36)       (Asias, 4)

# %%
# BARD
df_filt_neg_bard=df_filt_neg[df_filt_neg.Bert_topics.isin([1])]
ent_trend_bard = get_top_ents_2(df_filt_neg_bard)
ent_trend_bard
# Out:
#                             ORGANIZATION  \
# 0                         (Google, 2274)
# 1                       (Microsoft, 897)
# 2                         (ChatGPT, 884)
# 3                            (Bard, 844)
# 4                         (Googles, 774)
# 5                              (AI, 428)
# 6                      (Microsofts, 398)
# 7                        (Alphabet, 361)
# 8                          (OpenAI, 189)
# 9                         (Reuters, 160)
# 10                        (Twitter, 115)
# 11                           (Gebru, 98)
# 12  (the James Webb Space Telescope, 75)
# 13                      (Googles AI, 62)
# 14                           (Bards, 62)
# 15                           (Apple, 61)
# 16                         (Bard AI, 61)
# 17                            (A.I., 54)
# 18                       (Alphabets, 49)
# 19                           (Baidu, 46)
#
#                                           PRODUCT                PERSON  \
# 0                                      (AI, 1138)           (Bing, 273)
# 1                                     (Bing, 223)  (Sundar Pichai, 138)
# 2                                  (marketin, 27)           (Bard, 121)
# 3                                   (Windows, 18)          (Gebru, 104)
# 4                                (Windows 11, 17)          (Pichai, 83)
# 5                              (ChatGPTstyle, 13)            (JWST, 74)
# 6                                        (MX, 12)            (Dean, 66)
# 7                                  (AIdriven, 11)        (Mitchell, 49)
# 8                           (ChatGPTstyle AI, 11)    (Timnit Gebru, 42)
# 9                                   (Bing AI, 10)             (val, 33)
# 10                                   (Twitter, 9)           (Trump, 30)
# 11                                   (Bard AI, 9)         (Lemoine, 29)
# 12                           (professionalsto, 8)    (wellreviewed, 29)
# 13                                (AI Chatbot, 8)     (Angelo Zino, 29)
# 14                               (ChatGPT.Led, 7)           (Ernie, 29)
# 15  (Language Model for Dialogue Applications, 6)           (coCEO, 29)
# 16                                      (Lens, 6)       (Jeff Dean, 28)
# 17                                  (DeepMind, 6)      (enginelong, 28)
# 18                                   (YouTube, 5)      (Clay Bavor, 28)
# 19                        (MicrosoftGoogle AI, 5)           (Biden, 27)
#
#                 NORM
# 0     (European, 56)
# 1      (Chinese, 26)
# 2     (American, 15)
# 3      (Italian, 11)
# 4         (Asian, 9)
# 5    (Republican, 9)
# 6   (Republicans, 9)
# 7     (Americans, 9)
# 8        (German, 9)
# 9    (Accentures, 8)
# 10       (Texans, 7)
# 11      (Turkiye, 7)
# 12       (French, 6)
# 13     (Democrat, 6)
# 14        (Swiss, 6)
# 15      (British, 6)
# 16      (Popular, 5)
# 17          (ian, 5)
# 18      (Turkish, 4)
# 19        (Hindu, 4)

# %%
# PERSONAL ASSISTANT
df_filt_neg_snap=df_filt_neg[df_filt_neg.Bert_topics.isin([5])]
ent_trend_snap = get_top_ents_2(df_filt_neg_snap)
ent_trend_snap
# Out:
#                                          ORGANIZATION  \
# 0                                      (ChatGPT, 605)
# 1   (the Google Privacy Notice and Terms of Servic...
# 2                                           (AI, 138)
# 3                                     (Snapchat, 132)
# 4                                        (Google, 96)
# 5                                        (OpenAI, 81)
# 6      (Independent Press Standards Organisation, 62)
# 7                                 (SettingsTerms, 62)
# 8                                      (Facebook, 59)
# 9                                      (JobPlace, 55)
# 10                                        (Apple, 44)
# 11                                    (Microsoft, 42)
# 12                                 (Snapchatters, 31)
# 13                                       (ThisAI, 30)
# 14                                          (Wtf, 29)
# 15                                  (FeedRelated, 29)
# 16                        (World Publishing Ltd., 28)
# 17                 (McFly announce Power to Play, 28)
# 18                                      (Primark, 27)
# 19        (CharterNational World Publishing Ltd., 26)
#
#                                 PRODUCT                             PERSON  \
# 0                             (AI, 329)                    (Snapchat, 105)
# 1                   (GardenFashion, 53)              (Bryn Hargreaves, 33)
# 2                     (ReadPhoto  , 35)                        (botis, 32)
# 3                         (ChatGPT, 33)  (Dennis MortonPublished 20th, 31)
# 4                       (Snapchats, 31)    (SportWhats OnWhats OnArts, 29)
# 5                  (AdOne Snapchat, 19)   (usersBy Ayaan AliPublished, 29)
# 6                        (BlueMail, 14)                (Nina Warhurst, 25)
# 7                           (My AI, 11)                 (PopularMy AI, 25)
# 8   (GardenFashion and  NoticesFree, 7)                (Boris Johnson, 24)
# 9        (ReadPhoto  Links UsSubmit, 6)                         (Kang, 20)
# 10                            (Bing, 5)                   (Sam Altman, 18)
# 11                         (YouTube, 4)                  (Peter Hardy, 16)
# 12                    (BlenderBot 3, 4)                      (Charles, 14)
# 13                         (Open AI, 4)                        (Ariel, 13)
# 14                           (iPads, 4)                          (Lee, 12)
# 15                      (KapoorRhea, 4)               (OnWhats OnArts, 12)
# 16                        (Mattmann, 4)           (OnThings To DoArts, 12)
# 17                      (StoreRedmi, 4)                          (Tay, 11)
# 18                             (Pro, 3)                    (Elon Musk, 11)
# 19                        (Facebook, 3)                 (Ariana Madix, 10)
#
#                   NORM
# 0     (ChatGPTthe, 32)
# 1        (British, 27)
# 2       (American, 17)
# 3      (Snapchats, 12)
# 4       (Americans, 6)
# 5      (Democratic, 6)
# 6       (Ukrainian, 5)
# 7    (SITESEnglish, 4)
# 8          (Muslim, 3)
# 9   (ITVNeighbours, 3)
# 10       (Scottish, 3)
# 11        (FCWhats, 3)
# 12          (Hindu, 2)
# 13    (Fivehourold, 2)
# 14       (SunIrish, 2)
# 15        (Italian, 2)
# 16        (Sunsets, 2)
# 17         (Polish, 2)
# 18           (togo, 2)
# 19       (Micheles, 2)

# %%
# JOBS
df_filt_neg_jobs=df_filt_neg[df_filt_neg.Bert_topics.isin([8])]
ent_trend_jobs = get_top_ents_2(df_filt_neg_jobs)
ent_trend_jobs
# Out:
#                      ORGANIZATION                             PRODUCT  \
# 0                       (AI, 323)                           (AI, 390)
# 1                   (ChatGPT, 79)                     (callcenter, 5)
# 2                     (Apple, 68)                         (Citrix, 5)
# 3                    (Google, 66)                       (Checkout, 5)
# 4                 (Microsoft, 36)                         (Grammy, 5)
# 5                    (Amazon, 36)                (SingularityT AI, 5)
# 6                       (V19, 34)                   (SingularityT, 5)
# 7                       (TUC, 33)                      (Newsource, 4)
# 8              (Data Science, 30)                     (JavaScript, 3)
# 9                       (IBM, 22)  (AI Can Fill the Jobs GapThats, 3)
# 10  (Artificial Intelligence, 20)                 (Expandcollapse, 3)
# 11                 (Alphabet, 18)                      (DataRobot, 3)
# 12                      (BBC, 18)                       (HomeSkip, 3)
# 13                  (FE News, 17)                       (AIdriven, 2)
# 14         (Gray Media Group, 15)                   (andMicrosoft, 2)
# 15                  (Dropbox, 15)                        (Windows, 2)
# 16                 (Facebook, 13)                       (FireCuda, 2)
# 17                     (EEOC, 13)         (Windows 1025  BetaNews, 2)
# 18                 (LinkedIn, 13)                      (AIrelated, 2)
# 19            (Goldman Sachs, 13)                       (GiftShop, 2)
#
#                   PERSON                  NORM
# 0       (Goodfellow, 18)          (Apples, 23)
# 1   (Ian Goodfellow, 16)         (Chinese, 20)
# 2            (Harry, 15)        (American, 15)
# 3           (Meghan, 13)       (Americans, 11)
# 4   (Kristen Clarke, 12)          (British, 8)
# 5         (ParentRe, 11)         (European, 7)
# 6         (inperson, 10)          (Muslims, 5)
# 7              (Adam, 9)           (Aussie, 5)
# 8             (Biden, 9)          (Spanish, 4)
# 9         (Elon Musk, 9)            (Asian, 4)
# 10           (Marcel, 8)        (Democrats, 4)
# 11            (Trump, 8)       (Republican, 4)
# 12          (Collins, 8)           (French, 3)
# 13       (Joe Bidens, 8)        (Ukrainian, 3)
# 14             (Musk, 8)      (Republicans, 3)
# 15             (Frey, 8)          (Italian, 3)
# 16     (Harry Styles, 8)           (Beyonc, 3)
# 17          (Beyonce, 8)           (popins, 2)
# 18           (Watson, 7)  (SkillsWorldLive, 2)
# 19            (Oprah, 7)          (StoryTo, 2)
